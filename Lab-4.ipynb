# %%
# Opening, closing, appending, reading, and 
#displaying the properties of a file

# Open file in write mode
fo = open("dap.txt", "w")

# Write to a file
fo.write("Akash")

# Close file
fo.close()

# Open file in append mode
fo = open("dap.txt", "a")
fo.write("Yadav")
fo.close()

# Open and read the file after the appending:
fo = open("dap.txt", "r")
print(fo.read())

# Print properties of a file
print ("Name of the file: ", fo.name)
print ("Closed or not : ", fo.closed)
print ("Opening mode : ", fo.mode)

fo.close()
# Out:
# AkashYadav
# Name of the file:  dap.txt
# Closed or not :  False
# Opening mode :  r

# %%
# Checking current pointer position and
# seeking to a new position

fo = open("dap.txt", "r")
str = fo.read(4)
print ("Read String is : ", str)

# Check current position
position = fo.tell()
print ("Current file position : ", position)

# Reposition pointer at the beginning once again
position = fo.seek(1, 0);
str = fo.read(3)
print ("Again read String is : ", str)

fo.close()
# Out:
# Read String is :  Akas
# Current file position :  4
# Again read String is :  kas

# %%
# os functions such as renaming, removng a file
# creating, checking, changing, removing directories

import os

# Rename a file from dap.txt to test.txt
os.rename("dap.txt", "test.txt" )

# Delete file test.txt
os.remove("test.txt")

# This would give location of the current directory
print(os.getcwd())

# Create a directory "test"
os.mkdir("test")

# Changing a directory to "/home/newdir"
os.chdir("/content/test")

# This would  remove "/tmp/test"  directory.
os.rmdir( "/content/test"  )

# %%
# Creating, printing, print with index
# and deletion of tuples

# Creation of tuple
tup1= ('cse','it','mech','ece','electrical')
tup2=(1,23,4,5,5,6)

# Printing tuple
print(tup1)
print(tup2)

# Printing with index
print(tup1[0])
print(tup1[2])
print(tup1[2:5])

# Deletion of tuple
del(tup1)
del(tup2)
# Out:
# ('cse', 'it', 'mech', 'ece', 'electrical')
# (1, 23, 4, 5, 5, 6)
# cse
# mech
# ('mech', 'ece', 'electrical')

# %%
# Concatenation, finding length, and max element

tup1= ('cse','it','mech','ece','electrical')
print(tup1)
tup2= ('ali','roro','james')
print(tup2)

# Concatenation
tup3=tup1+tup2
print(tup3)

# Finding length
print("Length of first tuple is ",len(tup1))
print("Length of second tuple is ",len(tup2))

#Finding max element
print("Max element in first tuple is",max(tup1))
# Out:
# ('cse', 'it', 'mech', 'ece', 'electrical')
# ('ali', 'roro', 'james')
# ('cse', 'it', 'mech', 'ece', 'electrical', 'ali', 'roro', 'james')
# Length of first tuple is  5
# Length of second tuple is  3
# Max element in first tuple is mech

# %%
# Creating, printing, updation, appending
# Deleting a key, clearing/deleting the dictionary

# Creation of a dictionary
dict={'name':'Akash','designation':'student','course':'DAP','univ':'cmr'}

# Printing of dictionary elements
print(dict['name'])
print(dict['course'])
print(dict)

# Updating a value
dict['name']='Yadav'
print("After updating name-",dict['name'])

# Appending a value
dict['class']='cse7th sem'
print("After appending class-",dict['class'])

# Deleting a key
del dict['designation']
print("After removing designation-",dict)

# Clearing the dictionary
dict.clear()
print("After clearing dictionary-",dict)

# Deleting the dictionary
del dict
# Out:
# Akash
# DAP
# {'name': 'Akash', 'designation': 'student', 'course': 'DAP', 'univ': 'cmr'}
# After updating name- Yadav
# After appending class- cse7th sem
# After removing designation- {'name': 'Yadav', 'course': 'DAP', 'univ': 'cmr', 'class': 'cse7th sem'}
# After clearing dictionary- {}

# %%
# Printing properties of dictionaries

dict={'name':'akash','designation':'student','course':'DAP','univ':'cmr', 'name':'Yadav'}

# In case same key is given 2 values, latest will be considered
print(dict['name'])

# Length of dictionary
print(len(dict))

# Returns only the values
print(dict.values())

# Returns only the keys
print(dict.keys())

# Returns respective key-value pairs
print(dict.items())
# Out:
# Yadav
# 4
# dict_values(['Yadav', 'student', 'DAP', 'cmr'])
# dict_keys(['name', 'designation', 'course', 'univ'])
# dict_items([('name', 'Yadav'), ('designation', 'student'), ('course', 'DAP'), ('univ', 'cmr')])

# %%
# get(), copy(), and update() methods

dict={'name':'akash','designation':'student','course':'DAP','univ':'cmr', 'name':'Yadav'}

print(dict.get('name'))
print(dict.get('edu'))
print(dict.get('edu',"nothing"))

# copy() method is used to copy a dictionary
dict1=dict.copy()
print(dict1)

# update() method appends to a dictionary
dict2={'semester':'7sem'}
dict.update(dict2)
print(dict)
# Out:
# Yadav
# None
# nothing
# {'name': 'Yadav', 'designation': 'student', 'course': 'DAP', 'univ': 'cmr'}
# {'name': 'Yadav', 'designation': 'student', 'course': 'DAP', 'univ': 'cmr', 'semester': '7sem'}
